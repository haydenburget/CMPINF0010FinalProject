# %%
import pandas as pd

# %%
airqualityindex = pd.read_csv("https://data.wprdc.org/datastore/dump/4ab1e23f-3262-4bd3-adbf-f72f0119108b")

# %%
airqualityindex
# Out:
#              date               site parameter  index_value description  \
# 0      2016-01-01      Lawrenceville     PM25B           25        Good
# 1      2016-01-01         Flag Plaza        CO            0        Good
# 2      2016-01-01  Harrison Township     OZONE           31        Good
# 3      2016-01-01             Avalon       SO2           10        Good
# 4      2016-01-01            Lincoln      PM25           35        Good
# ...           ...                ...       ...          ...         ...
# 47840  2021-11-14      South Fayette       SO2            0        Good
# 47841  2021-11-14         Pittsburgh  PM25_640           28        Good
# 47842  2021-11-14          Liberty 2     PM25T           23        Good
# 47843  2021-11-14       Parkway East     PM25T           18        Good
# 47844  2021-11-14             Avalon     PM25T           19        Good
#
#       health_advisory health_effects
# 0                 NaN            NaN
# ...

# %%
artdata = pd.read_csv("https://data.wprdc.org/datastore/dump/00d74e83-8a23-486e-841b-286e1332a151")

# %%
airqualityindex.groupby('site')['index_value'].mean()
# Out:
# site
# Avalon                   20.694054
# Clairton                  7.273556
# Flag Plaza                9.853728
# Glassport High Street    17.267731
# Harrison Township        24.363148
# Lawrenceville            38.468050
# Lawrenceville 2           3.107261
# Liberty                  18.781046
# Liberty 2                32.353250
# Lincoln                  35.108002
# North Braddock           17.986943
# Parkway East             22.310798
# Pittsburgh               29.984424
# South Fayette            20.621667
# West Mifflin              6.335548
# Name: index_value, dtype: float64

# %%
artdata
# Out:
#              id        name                              title  \
# 0     812728309        1001              Oakwood Road Monument
# 1     188255168        1002  Rooster Waiting For The Streetcar
# 2    2032091917         129        Middle East Memorial Plaque
# 3    1447629273         143                           L'Enfant
# 4    1935017944         148      Veterans Memorial (Brookline)
# ..          ...         ...                                ...
# 194  1089921133  WM00099000        17th Ward Veterans Memorial
# 195   191395610  WM00101000          Saint Josephat Honor Roll
# 196   628976107  WM00102000              World War II Momument
# 197  1309894649  WM00105000       Korean War Veterans Memorial
# 198  1903851764  WM00107000          Vietnam Veterans Memorial
#
#                            artist_name                     art_type  \
# 0                                  NaN                          NaN
# 1                          James Simon  Modern and Contemporary Art
# ...

# %%
artdata.groupby('neighborhood')['neighborhood'].count()
# Out:
# neighborhood
# Allegheny Center             18
# Allegheny West                1
# Allentown                     2
# Beechview                     7
# Beltzhoover                   3
# Bloomfield                    1
# Brighton Heights              5
# Brookline                     2
# Carrick                       2
# Central Business District    27
# Central Lawrenceville         2
# Central Oakland               5
# Crafton Heights               1
# Crawford-Roberts              3
# Duquesne Heights              3
# East Allegheny                2
# East Carnegie                 1
# East Hills                    1
# East Liberty                  1
# Elliott                       3
# Esplen                        1
# Garfield                      2
# Greenfield                    3
# Hays                          1
# Hazelwood                     3
# Highland Park                10
# Knoxville                     1
# Lincoln-Lemington-Belmar      2
# ...
